# %%
from mapboxgl_notebook.map import MapboxMap
from mapboxgl_notebook.sources import GeoJSONSource
from mapboxgl_notebook.layers import PointCircleLayer, LineStringLineLayer, PolygonFillLayer
from mapboxgl_notebook.properties import Paint
from mapboxgl_notebook.interactions import ClickInteraction, HoverInteraction
from mapboxgl.utils import *
import pandas as pd

# %%
df = pd.read_csv("data/jakarta_timur_pois.txt",sep="|").round(4)
df.head()
# Out:
#                name     lat       lng               street  number
# 0           Kranji  -6.2245  106.9800    Jl. Sultan Agung     No.7
# 1   Duren Kalibata  -6.2553  106.8552      Jl. Pengadegan        0
# 2     Menteng Huis  -6.1878  106.8364   Jalan Cikini Raya    no. 4
# 3  Farmer's Market  -6.2183  106.8351                 nil        0
# 4        Superindo  -6.2489  106.9691                 nil        0

# %%
token = 'MAPBOX_ACCESS_TOKEN'

# %%
# Create a geojson file export from the current dataframe
df_to_geojson(df, 
              filename='data/jakarta_timur_poi.geojson',
              properties=['name','street','number'], 
              lat='lat', 
              lon='lng', 
              precision=3)
# Out:
# {'type': 'file',
#  'filename': 'data/jakarta_timur_poi.geojson',
#  'feature_count': 1178}

# %%
# Definition of source
data = 'data/jakarta_timur_poi.geojson'
source = GeoJSONSource(data, source_id='points')
# Layer (geojson type Point, mapboxgl type Circle)
layer = PointCircleLayer(source)
# Hover interaction (popup with property name)
hover = HoverInteraction(layer, properties=['name'])
# Map rendering
mapbox_map = MapboxMap(
    access_token=token,
    center=[106.8,-6.2],
    sources=[source],  # can be list of sources
    layers=[layer],  # can be list of layers
    interactions=[hover]
)
mapbox_map.show()
# Out:
# <iframe id="map", srcdoc="<!DOCTYPE html>
# <html>
# <head>
#     <meta charset='utf-8' />
#     <title>map</title>
#     <meta name='viewport' content='initial-scale=1,maximum-scale=1,user-scalable=no' />
#     <script src='https://api.tiles.mapbox.com/mapbox-gl-js/v0.52.0/mapbox-gl.js'></script>
#     <link href='https://api.tiles.mapbox.com/mapbox-gl-js/v0.52.0/mapbox-gl.css' rel='stylesheet' />
#     <style>
#         body { margin:0; padding:0; }
#         #map { position:absolute; top:0; bottom:0; width:100%; }
#     </style>
# </head>
# <body>
# <div id='map'></div>
#
#
# <script>
# mapboxgl.accessToken = 'pk.eyJ1IjoiYmhhdHRhY2hhcnl5YSIsImEiOiJjanphMW41NTAwMDIwM21udWhsNWF0ZHJhIn0.wcJsBPBPi6zR5ivLav564A';
# var map = new mapboxgl.Map({
#     container: 'map', // container id
#     style: 'mapbox://styles/mapbox/streets-v9', // stylesheet location
#     center: [106.8, -6.2], // starting position [lng, lat]
#     zoom: 10 // starting zoom
# });
#
#
# let sources = [{&#34;id&#34;: &#34;points&#34;, &#34;data&#34;: &#34;data/jakarta_timur_poi.geojson&#34;, &#34;type&#34;: &#34;geojson&#34;}];
# let layers = [{&#34;id&#34;: &#34;Point_points&#34;, &#34;source&#34;: &#34;points&#34;, &#34;type&#34;: &#34;circle&#34;, &#34;paint&#34;: {&#34;circle-radius&#34;: 4, &#34;circle-color&#34;: &#34;#0000ff&#34;}, &#34;filter&#34;: [&#34;==&#34;, [&#34;geometry-type&#34;], &#34;Point&#34;], &#34;below_layer_id&#34;: null}];
# let interactions = [{&#34;layer_id&#34;: &#34;Point_points&#34;, &#34;interaction_type&#34;: &#34;hover&#34;, &#34;properties&#34;: [&#34;name&#34;]}];
# let popups = {};
#
#
# map.on('load', function(){
#
#   for (let i=0; i < sources.length; i++) {
#     let source = sources[i];
#     map.addSource(
#         source.id, {
#         'type': source.type,
#         'data': source.data
#     });
#   }
#
#   for (let i=0; i < layers.length; i++) {
#       if (map.getLayer(layers[i]['id']) === undefined) {
#           if (layers[i]['below_layer_id'] === null) {
#             map.addLayer(layers[i]);
#           } else {
#             map.addLayer(layers[i], layers[i]['below_layer_id']);
#           }
#       }
#   }
#
#   var popup_content = function(feature, properties) {
#       var html = '';
#       var property_value;
#       if (properties === '*') {
#         for (let i in feature.properties) {
#           property_value = feature.properties[i];
#           html = html + '<div>' + i + ' : ' + property_value + '</div>';
#         }
#       } else {
#         for (let i in feature.properties) {
#           if ( properties.includes(i) ) {
#             property_value = feature.properties[i];
#             html = html + '<div>' + i + ' : ' + property_value + '</div>';
#           }
#         }
#       }
#       return html;
#   }
#
#   var addPopupInteraction = function(layer_id, properties, interaction_type) {
#     var map_event;
#     popups[layer_id] = new mapboxgl.Popup();
#     if (interaction_type === 'hover') {
#       map_event = 'mousemove';
#     }
#     else if (interaction_type === 'click') {
#       map_event = 'click';
#     }
#
#     map.on('mousemove', function(e) {
#       if (map.getLayer(layer_id) === undefined) {
#         return;
#       }
#       var features = map.queryRenderedFeatures(e.point, {
#           layers: [
#             layer_id
#           ]
#       });
#       map.getCanvas().style.cursor = (features.length) ? 'pointer' : '';
#     });
#
#     map.on(map_event, function(e) {
#         var popup = popups[layer_id];
#         if (map.getLayer(layer_id) === undefined) {
#           return;
#         }
#         var features = map.queryRenderedFeatures(e.point, {
#             layers: [
#               layer_id
#             ]
#         });
#         if (!features.length) {
#             popup.remove();
#             return;
#         }
#         var coordinates = [e.lngLat.lng, e.lngLat.lat];
#         var description = popup_content(features[0], properties);
#         while (Math.abs(e.lngLat.lng - coordinates[0]) > 180) {
#             coordinates[0] += e.lngLat.lng > coordinates[0] ? 360 : -360;
#         }
#         popup.setLngLat(coordinates)
#             .setHTML(description)
#             .addTo(map);
#       });
#   }
#
#   for (let i=0; i < interactions.length; i++) {
#     let interaction = interactions[i];
#     if (['hover', 'click'].includes(interaction.interaction_type)){
#       addPopupInteraction(
#         interaction.layer_id,
#         interaction.properties,
#         interaction.interaction_type
#       );
#     }
#   }
#
# });
# </script>
#
#
# </body>
# </html>" style="width: 100%; height: 500px;"></iframe>

# %%
# Polygon layer
data = 'data/jakarta_timur_boundary.geojson'
source = GeoJSONSource(data, source_id='name')
paint = Paint(
    fill_color='rgba(200, 100, 240, 0.4)',
    fill_outline_color='rgba(200, 100, 240, 1)'
)
layer2 = PolygonFillLayer(source, paint=paint)
interaction = ClickInteraction(layer)
mapbox_map = MapboxMap(
    center=[106.8,-6.2],
    zoom=6,
    access_token=token,
    sources=[source],
    layers=[layer2],
    interactions=[interaction]
)
mapbox_map.show()
# Out:
# <iframe id="map", srcdoc="<!DOCTYPE html>
# <html>
# <head>
#     <meta charset='utf-8' />
#     <title>map</title>
#     <meta name='viewport' content='initial-scale=1,maximum-scale=1,user-scalable=no' />
#     <script src='https://api.tiles.mapbox.com/mapbox-gl-js/v0.52.0/mapbox-gl.js'></script>
#     <link href='https://api.tiles.mapbox.com/mapbox-gl-js/v0.52.0/mapbox-gl.css' rel='stylesheet' />
#     <style>
#         body { margin:0; padding:0; }
#         #map { position:absolute; top:0; bottom:0; width:100%; }
#     </style>
# </head>
# <body>
# <div id='map'></div>
#
#
# <script>
# mapboxgl.accessToken = 'pk.eyJ1IjoiYmhhdHRhY2hhcnl5YSIsImEiOiJjanphMW41NTAwMDIwM21udWhsNWF0ZHJhIn0.wcJsBPBPi6zR5ivLav564A';
# var map = new mapboxgl.Map({
#     container: 'map', // container id
#     style: 'mapbox://styles/mapbox/streets-v9', // stylesheet location
#     center: [106.8, -6.2], // starting position [lng, lat]
#     zoom: 6 // starting zoom
# });
#
#
# let sources = [{&#34;id&#34;: &#34;name&#34;, &#34;data&#34;: &#34;data/jakarta_timur_boundary.geojson&#34;, &#34;type&#34;: &#34;geojson&#34;}];
# let layers = [{&#34;id&#34;: &#34;Polygon_name&#34;, &#34;source&#34;: &#34;name&#34;, &#34;type&#34;: &#34;fill&#34;, &#34;paint&#34;: {&#34;fill-color&#34;: &#34;rgba(200, 100, 240, 0.4)&#34;, &#34;fill-outline-color&#34;: &#34;rgba(200, 100, 240, 1)&#34;}, &#34;filter&#34;: [&#34;==&#34;, [&#34;geometry-type&#34;], &#34;Polygon&#34;], &#34;below_layer_id&#34;: null}];
# let interactions = [{&#34;layer_id&#34;: &#34;Point_points&#34;, &#34;interaction_type&#34;: &#34;click&#34;, &#34;properties&#34;: &#34;*&#34;}];
# let popups = {};
#
#
# map.on('load', function(){
#
#   for (let i=0; i < sources.length; i++) {
#     let source = sources[i];
#     map.addSource(
#         source.id, {
#         'type': source.type,
#         'data': source.data
#     });
#   }
#
#   for (let i=0; i < layers.length; i++) {
#       if (map.getLayer(layers[i]['id']) === undefined) {
#           if (layers[i]['below_layer_id'] === null) {
#             map.addLayer(layers[i]);
#           } else {
#             map.addLayer(layers[i], layers[i]['below_layer_id']);
#           }
#       }
#   }
#
#   var popup_content = function(feature, properties) {
#       var html = '';
#       var property_value;
#       if (properties === '*') {
#         for (let i in feature.properties) {
#           property_value = feature.properties[i];
#           html = html + '<div>' + i + ' : ' + property_value + '</div>';
#         }
#       } else {
#         for (let i in feature.properties) {
#           if ( properties.includes(i) ) {
#             property_value = feature.properties[i];
#             html = html + '<div>' + i + ' : ' + property_value + '</div>';
#           }
#         }
#       }
#       return html;
#   }
#
#   var addPopupInteraction = function(layer_id, properties, interaction_type) {
#     var map_event;
#     popups[layer_id] = new mapboxgl.Popup();
#     if (interaction_type === 'hover') {
#       map_event = 'mousemove';
#     }
#     else if (interaction_type === 'click') {
#       map_event = 'click';
#     }
#
#     map.on('mousemove', function(e) {
#       if (map.getLayer(layer_id) === undefined) {
#         return;
#       }
#       var features = map.queryRenderedFeatures(e.point, {
#           layers: [
#             layer_id
#           ]
#       });
#       map.getCanvas().style.cursor = (features.length) ? 'pointer' : '';
#     });
#
#     map.on(map_event, function(e) {
#         var popup = popups[layer_id];
#         if (map.getLayer(layer_id) === undefined) {
#           return;
#         }
#         var features = map.queryRenderedFeatures(e.point, {
#             layers: [
#               layer_id
#             ]
#         });
#         if (!features.length) {
#             popup.remove();
#             return;
#         }
#         var coordinates = [e.lngLat.lng, e.lngLat.lat];
#         var description = popup_content(features[0], properties);
#         while (Math.abs(e.lngLat.lng - coordinates[0]) > 180) {
#             coordinates[0] += e.lngLat.lng > coordinates[0] ? 360 : -360;
#         }
#         popup.setLngLat(coordinates)
#             .setHTML(description)
#             .addTo(map);
#       });
#   }
#
#   for (let i=0; i < interactions.length; i++) {
#     let interaction = interactions[i];
#     if (['hover', 'click'].includes(interaction.interaction_type)){
#       addPopupInteraction(
#         interaction.layer_id,
#         interaction.properties,
#         interaction.interaction_type
#       );
#     }
#   }
#
# });
# </script>
#
#
# </body>
# </html>" style="width: 100%; height: 500px;"></iframe>

# %%
data1 = 'data/jakarta_timur_poi.geojson'
source1 = GeoJSONSource(data1, source_id='points')
# Layer (geojson type Point, mapboxgl type Circle)
paint=Paint(
    circle_radius=2, 
    circle_color='#00ff00'
)
layer1 = PointCircleLayer(source1,paint=paint)
# Hover interaction (popup with property name)

data2 = 'data/jakarta_timur_boundary.geojson'
source2 = GeoJSONSource(data2, source_id='name')
paint2 = Paint(
    fill_color='rgba(240, 255, 0, 0)',
    fill_outline_color='rgba(255, 255, 255, 1)'
)
layer2 = PolygonFillLayer(source2,paint=paint2)
interaction = ClickInteraction(layer)


mapbox_map = MapboxMap(
    center=[106.8,-6.2],
    zoom=9,
    access_token=token,
    sources=[source1, source2],
    layers=[layer1, layer2],
    interactions=[interaction],
    style='mapbox://styles/mapbox/dark-v10?optimize=true'
)
mapbox_map.show()
# Out:
# <iframe id="map", srcdoc="<!DOCTYPE html>
# <html>
# <head>
#     <meta charset='utf-8' />
#     <title>map</title>
#     <meta name='viewport' content='initial-scale=1,maximum-scale=1,user-scalable=no' />
#     <script src='https://api.tiles.mapbox.com/mapbox-gl-js/v0.52.0/mapbox-gl.js'></script>
#     <link href='https://api.tiles.mapbox.com/mapbox-gl-js/v0.52.0/mapbox-gl.css' rel='stylesheet' />
#     <style>
#         body { margin:0; padding:0; }
#         #map { position:absolute; top:0; bottom:0; width:100%; }
#     </style>
# </head>
# <body>
# <div id='map'></div>
#
#
# <script>
# mapboxgl.accessToken = 'pk.eyJ1IjoiYmhhdHRhY2hhcnl5YSIsImEiOiJjanphMW41NTAwMDIwM21udWhsNWF0ZHJhIn0.wcJsBPBPi6zR5ivLav564A';
# var map = new mapboxgl.Map({
#     container: 'map', // container id
#     style: 'mapbox://styles/mapbox/dark-v10?optimize=true', // stylesheet location
#     center: [106.8, -6.2], // starting position [lng, lat]
#     zoom: 9 // starting zoom
# });
#
#
# let sources = [{&#34;id&#34;: &#34;points&#34;, &#34;data&#34;: &#34;data/jakarta_timur_poi.geojson&#34;, &#34;type&#34;: &#34;geojson&#34;}, {&#34;id&#34;: &#34;name&#34;, &#34;data&#34;: &#34;data/jakarta_timur_boundary.geojson&#34;, &#34;type&#34;: &#34;geojson&#34;}];
# let layers = [{&#34;id&#34;: &#34;Point_points&#34;, &#34;source&#34;: &#34;points&#34;, &#34;type&#34;: &#34;circle&#34;, &#34;paint&#34;: {&#34;circle-radius&#34;: 2, &#34;circle-color&#34;: &#34;#00ff00&#34;}, &#34;filter&#34;: [&#34;==&#34;, [&#34;geometry-type&#34;], &#34;Point&#34;], &#34;below_layer_id&#34;: null}, {&#34;id&#34;: &#34;Polygon_name&#34;, &#34;source&#34;: &#34;name&#34;, &#34;type&#34;: &#34;fill&#34;, &#34;paint&#34;: {&#34;fill-color&#34;: &#34;rgba(240, 255, 0, 0)&#34;, &#34;fill-outline-color&#34;: &#34;rgba(255, 255, 255, 1)&#34;}, &#34;filter&#34;: [&#34;==&#34;, [&#34;geometry-type&#34;], &#34;Polygon&#34;], &#34;below_layer_id&#34;: null}];
# let interactions = [{&#34;layer_id&#34;: &#34;Point_points&#34;, &#34;interaction_type&#34;: &#34;click&#34;, &#34;properties&#34;: &#34;*&#34;}];
# let popups = {};
#
#
# map.on('load', function(){
#
#   for (let i=0; i < sources.length; i++) {
#     let source = sources[i];
#     map.addSource(
#         source.id, {
#         'type': source.type,
#         'data': source.data
#     });
#   }
#
#   for (let i=0; i < layers.length; i++) {
#       if (map.getLayer(layers[i]['id']) === undefined) {
#           if (layers[i]['below_layer_id'] === null) {
#             map.addLayer(layers[i]);
#           } else {
#             map.addLayer(layers[i], layers[i]['below_layer_id']);
#           }
#       }
#   }
#
#   var popup_content = function(feature, properties) {
#       var html = '';
#       var property_value;
#       if (properties === '*') {
#         for (let i in feature.properties) {
#           property_value = feature.properties[i];
#           html = html + '<div>' + i + ' : ' + property_value + '</div>';
#         }
#       } else {
#         for (let i in feature.properties) {
#           if ( properties.includes(i) ) {
#             property_value = feature.properties[i];
#             html = html + '<div>' + i + ' : ' + property_value + '</div>';
#           }
#         }
#       }
#       return html;
#   }
#
#   var addPopupInteraction = function(layer_id, properties, interaction_type) {
#     var map_event;
#     popups[layer_id] = new mapboxgl.Popup();
#     if (interaction_type === 'hover') {
#       map_event = 'mousemove';
#     }
#     else if (interaction_type === 'click') {
#       map_event = 'click';
#     }
#
#     map.on('mousemove', function(e) {
#       if (map.getLayer(layer_id) === undefined) {
#         return;
#       }
#       var features = map.queryRenderedFeatures(e.point, {
#           layers: [
#             layer_id
#           ]
#       });
#       map.getCanvas().style.cursor = (features.length) ? 'pointer' : '';
#     });
#
#     map.on(map_event, function(e) {
#         var popup = popups[layer_id];
#         if (map.getLayer(layer_id) === undefined) {
#           return;
#         }
#         var features = map.queryRenderedFeatures(e.point, {
#             layers: [
#               layer_id
#             ]
#         });
#         if (!features.length) {
#             popup.remove();
#             return;
#         }
#         var coordinates = [e.lngLat.lng, e.lngLat.lat];
#         var description = popup_content(features[0], properties);
#         while (Math.abs(e.lngLat.lng - coordinates[0]) > 180) {
#             coordinates[0] += e.lngLat.lng > coordinates[0] ? 360 : -360;
#         }
#         popup.setLngLat(coordinates)
#             .setHTML(description)
#             .addTo(map);
#       });
#   }
#
#   for (let i=0; i < interactions.length; i++) {
#     let interaction = interactions[i];
#     if (['hover', 'click'].includes(interaction.interaction_type)){
#       addPopupInteraction(
#         interaction.layer_id,
#         interaction.properties,
#         interaction.interaction_type
#       );
#     }
#   }
#
# });
# </script>
#
#
# </body>
# </html>" style="width: 100%; height: 500px;"></iframe>

# %%
with open('mapbox.html', 'w') as f:
    f.write(mapbox_map.create_html())
